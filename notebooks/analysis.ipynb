# %% [markdown]
# # 0. Imports

# %%
from pathlib import Path
from src.io import build_dataframes
from src.cleaning import clean_metadata

# %% [markdown]
# # 1. Data loading

# %%
zip_path = Path("..") / "data" / "raw" / "query.zip"
df_meta, df_acc = build_dataframes(zip_path)

# %% [markdown]
# # 2. Data exploration

# %%
# Shape
print("Metadata DataFrame shape:", df_meta.shape)
print("Acceleration DataFrame shape:", df_acc.shape)

# Columns
print("\nMetadata columns:")
for col in df_meta.columns:
    print(f"  {col}")

# Data types
print("\nColumn types distribution:")
print(df_meta.dtypes.value_counts())

# Missing values
print("Missing values (NaN) in raw df_meta:")
print(df_meta.isnull().sum().sum())

# Sample
print("\nFirst 2 rows:")
print(df_meta.head(2).to_dict())
# Out:
# Metadata DataFrame shape: (66, 65)
# Acceleration DataFrame shape: (2614815, 3)
#
# Metadata columns:
#   file
#   EVENT_NAME
#   EVENT_ID
#   EVENT_DATE_YYYYMMDD
#   EVENT_TIME_HHMMSS
#   EVENT_LATITUDE_DEGREE
#   EVENT_LONGITUDE_DEGREE
#   EVENT_DEPTH_KM
#   HYPOCENTER_REFERENCE
#   MAGNITUDE_W
#   MAGNITUDE_W_REFERENCE
#   MAGNITUDE_L
#   MAGNITUDE_L_REFERENCE
#   FOCAL_MECHANISM
#   NETWORK
#   STATION_CODE
#   STATION_NAME
#   STATION_LATITUDE_DEGREE
#   STATION_LONGITUDE_DEGREE
#   STATION_ELEVATION_M
#   LOCATION
#   SENSOR_DEPTH_M
#   VS30_M/S
#   SITE_CLASSIFICATION_EC8
#   MORPHOLOGIC_CLASSIFICATION
#   EPICENTRAL_DISTANCE_KM
#   EARTHQUAKE_BACKAZIMUTH_DEGREE
#   DATE_TIME_FIRST_SAMPLE_YYYYMMDD_HHMMSS
#   DATE_TIME_FIRST_SAMPLE_PRECISION
#   SAMPLING_INTERVAL_S
#   NDATA
#   DURATION_S
#   STREAM
#   UNITS
#   INSTRUMENT
#   INSTRUMENT_ANALOG/DIGITAL
#   INSTRUMENTAL_FREQUENCY_HZ
#   INSTRUMENTAL_DAMPING
#   FULL_SCALE_G
#   N_BIT_DIGITAL_CONVERTER
#   PGA_CM/S^2
#   TIME_PGA_S
#   BASELINE_CORRECTION
#   FILTER_TYPE
#   FILTER_ORDER
#   LOW_CUT_FREQUENCY_HZ
#   HIGH_CUT_FREQUENCY_HZ
#   LATE/NORMAL_TRIGGERED
#   DATABASE_VERSION
#   HEADER_FORMAT
#   DATA_TYPE
#   PROCESSING
#   DATA_TIMESTAMP_YYYYMMDD_HHMMSS
#   DATA_LICENSE
#   DATA_CITATION
#   DATA_CREATOR
#   ORIGINAL_DATA_MEDIATOR_CITATION
#   ORIGINAL_DATA_MEDIATOR
#   ORIGINAL_DATA_CREATOR_CITATION
#   ORIGINAL_DATA_CREATOR
#   USER1
#   USER2
#   USER3
#   USER4
#   USER5
#
# Column types distribution:
# object    65
# Name: count, dtype: int64
# Missing values (NaN) in raw df_meta:
# 0
#
# First 2 rows:
# {'file': {0: 'FR.EILF.00.HNE.D.INT-41004391.ACC.MP.ASC', 1: 'FR.EILF.00.HNN.D.INT-41004391.ACC.MP.ASC'}, 'EVENT_NAME': {0: 'None', 1: 'None'}, 'EVENT_ID': {0: 'INT-41004391', 1: 'INT-41004391'}, 'EVENT_DATE_YYYYMMDD': {0: '20241209', 1: '20241209'}, 'EVENT_TIME_HHMMSS': {0: '104121', 1: '104121'}, 'EVENT_LATITUDE_DEGREE': {0: '44.5127', 1: '44.5127'}, 'EVENT_LONGITUDE_DEGREE': {0: '6.8533', 1: '6.8533'}, 'EVENT_DEPTH_KM': {0: '10.4', 1: '10.4'}, 'HYPOCENTER_REFERENCE': {0: 'INGV-BULLETIN', 1: 'INGV-BULLETIN'}, 'MAGNITUDE_W': {0: '3.8', 1: '3.8'}, 'MAGNITUDE_W_REFERENCE': {0: 'INGV-TERREMOTI', 1: 'INGV-TERREMOTI'}, 'MAGNITUDE_L': {0: '', 1: ''}, 'MAGNITUDE_L_REFERENCE': {0: '', 1: ''}, 'FOCAL_MECHANISM': {0: 'Strike-slip faulting', 1: 'Strike-slip faulting'}, 'NETWORK': {0: 'FR', 1: 'FR'}, 'STATION_CODE': {0: 'EILF', 1: 'EILF'}, 'STATION_NAME': {0: 'VILLA EILENROC', 1: 'VILLA EILENROC'}, 'STATION_LATITUDE_DEGREE': {0: '43.547900', 1: '43.547900'}, 'STATION_LONGITUDE_DEGREE': {0: '7.131200', 1: '7.131200'}, 'STATION_ELEVATION_M': {0: '30', 1: '30'}, 'LOCATION': {0: '00', 1: '00'}, 'SENSOR_DEPTH_M': {0: '0.0', 1: '0.0'}, 'VS30_M/S': {0: '', 1: ''}, 'SITE_CLASSIFICATION_EC8': {0: 'B (inferred from topography)', 1: 'B (inferred from topography)'}, 'MORPHOLOGIC_CLASSIFICATION': {0: '', 1: ''}, 'EPICENTRAL_DISTANCE_KM': {0: '109.5', 1: '109.5'}, 'EARTHQUAKE_BACKAZIMUTH_DEGREE': {0: '168.2', 1: '168.2'}, 'DATE_TIME_FIRST_SAMPLE_YYYYMMDD_HHMMSS': {0: '20241209_104040.000', 1: '20241209_104040.000'}, 'DATE_TIME_FIRST_SAMPLE_PRECISION': {0: 'milliseconds', 1: 'milliseconds'}, 'SAMPLING_INTERVAL_S': {0: '0.005000', 1: '0.005000'}, 'NDATA': {0: '48000', 1: '48000'}, 'DURATION_S': {0: '240.000', 1: '240.000'}, 'STREAM': {0: 'HNE', 1: 'HNN'}, 'UNITS': {0: 'cm/s^2', 1: 'cm/s^2'}, 'INSTRUMENT': {0: 'HN', 1: 'HN'}, 'INSTRUMENT_ANALOG/DIGITAL': {0: 'D', 1: 'D'}, 'INSTRUMENTAL_FREQUENCY_HZ': {0: '', 1: ''}, 'INSTRUMENTAL_DAMPING': {0: '', 1: ''}, 'FULL_SCALE_G': {0: '', 1: ''}, 'N_BIT_DIGITAL_CONVERTER': {0: '', 1: ''}, 'PGA_CM/S^2': {0: '0.376358', 1: '0.379116'}, 'TIME_PGA_S': {0: '78.870000', 1: '78.740000'}, 'BASELINE_CORRECTION': {0: 'BASELINE REMOVED', 1: 'BASELINE REMOVED'}, 'FILTER_TYPE': {0: 'BUTTERWORTH', 1: 'BUTTERWORTH'}, 'FILTER_ORDER': {0: '2', 1: '2'}, 'LOW_CUT_FREQUENCY_HZ': {0: '0.500', 1: '0.500'}, 'HIGH_CUT_FREQUENCY_HZ': {0: '40.000', 1: '40.000'}, 'LATE/NORMAL_TRIGGERED': {0: 'NT', 1: 'NT'}, 'DATABASE_VERSION': {0: '0.5', 1: '0.5'}, 'HEADER_FORMAT': {0: 'DYNA 1.2', 1: 'DYNA 1.2'}, 'DATA_TYPE': {0: 'ACCELERATION', 1: 'ACCELERATION'}, 'PROCESSING': {0: 'manual (Paolucci et al., 2011)', 1: 'manual (Paolucci et al., 2011)'}, 'DATA_TIMESTAMP_YYYYMMDD_HHMMSS': {0: '20250929_103207.865', 1: '20250929_103208.060'}, 'DATA_LICENSE': {0: 'D (network default license)', 1: 'D (network default license)'}, 'DATA_CITATION': {0: 'Felicetta C., Russo E., D Amico M., Sgobba S., Lanzano G., Mascandola C., Pacor F., Luzi L. (2023) Italian Accelerometric Archive v 4.0 - Istituto Nazionale di Geofisica e Vulcanologia, Dipartimento della Protezione Civile Nazionale. doi: 10.13127/itaca.4.0', 1: 'Felicetta C., Russo E., D Amico M., Sgobba S., Lanzano G., Mascandola C., Pacor F., Luzi L. (2023) Italian Accelerometric Archive v 4.0 - Istituto Nazionale di Geofisica e Vulcanologia, Dipartimento della Protezione Civile Nazionale. doi: 10.13127/itaca.4.0'}, 'DATA_CREATOR': {0: 'ITACA working group', 1: 'ITACA working group'}, 'ORIGINAL_DATA_MEDIATOR_CITATION': {0: '', 1: ''}, 'ORIGINAL_DATA_MEDIATOR': {0: 'http://ws.resif.fr/', 1: 'http://ws.resif.fr/'}, 'ORIGINAL_DATA_CREATOR_CITATION': {0: 'RESIF. (1995). RESIF-RLBP French Broad-band network, RESIF-RAP strong motion network and other seismic stations in metropolitan France. RESIF - Reseau Sismologique et geodesique Francais. https://doi.org/10.15778/RESIF.FR http://www.fdsn.org/networks/detail/FR/', 1: 'RESIF. (1995). RESIF-RLBP French Broad-band network, RESIF-RAP strong motion network and other seismi ...

# %% [markdown]
# `isnull()` returns 0 for all columns because missing values are encoded as empty strings `''` or the string `'None'`, not as `NaN`. This will be addressed in the preprocessing step.

# %% [markdown]
# # 3. Data preprocessing

# %%
df_meta_clean = clean_metadata(df_meta)
print(df_meta_clean.dtypes)
print(df_meta_clean.isnull().sum())
# Out:
# file                                        object
# EVENT_ID                                    object
# EVENT_LATITUDE_DEGREE                      float64
# EVENT_LONGITUDE_DEGREE                     float64
# EVENT_DEPTH_KM                             float64
# HYPOCENTER_REFERENCE                        object
# MAGNITUDE_W                                float64
# MAGNITUDE_W_REFERENCE                       object
# FOCAL_MECHANISM                             object
# NETWORK                                     object
# STATION_CODE                                object
# STATION_NAME                                object
# STATION_LATITUDE_DEGREE                    float64
# STATION_LONGITUDE_DEGREE                   float64
# STATION_ELEVATION_M                          int64
# LOCATION                                    object
# SENSOR_DEPTH_M                             float64
# SITE_CLASSIFICATION_EC8                     object
# EPICENTRAL_DISTANCE_KM                     float64
# EARTHQUAKE_BACKAZIMUTH_DEGREE              float64
# DATE_TIME_FIRST_SAMPLE_PRECISION            object
# SAMPLING_INTERVAL_S                        float64
# NDATA                                        int64
# DURATION_S                                 float64
# STREAM                                      object
# UNITS                                       object
# INSTRUMENT                                  object
# INSTRUMENT_ANALOG/DIGITAL                   object
# PGA_CM/S^2                                 float64
# TIME_PGA_S                                 float64
# BASELINE_CORRECTION                         object
# FILTER_TYPE                                 object
# FILTER_ORDER                                 int64
# LOW_CUT_FREQUENCY_HZ                       float64
# HIGH_CUT_FREQUENCY_HZ                      float64
# LATE/NORMAL_TRIGGERED                       object
# DATA_TYPE                                   object
# PROCESSING                                  object
# DATA_TIMESTAMP_YYYYMMDD_HHMMSS              object
# ORIGINAL_DATA_MEDIATOR                      object
# EVENT_DATE                          datetime64[ns]
# DATE_TIME_FIRST_SAMPLE              datetime64[ns]
# CHANNEL                                     object
# dtype: object
# file                                 0
# EVENT_ID                             0
# EVENT_LATITUDE_DEGREE                0
# EVENT_LONGITUDE_DEGREE               0
# EVENT_DEPTH_KM                       0
# HYPOCENTER_REFERENCE                 0
# MAGNITUDE_W                          0
# MAGNITUDE_W_REFERENCE                0
# FOCAL_MECHANISM                      0
# NETWORK                              0
# STATION_CODE                         0
# STATION_NAME                         0
# STATION_LATITUDE_DEGREE              0
# STATION_LONGITUDE_DEGREE             0
# STATION_ELEVATION_M                  0
# LOCATION                            15
# SENSOR_DEPTH_M                       0
# SITE_CLASSIFICATION_EC8             18
# EPICENTRAL_DISTANCE_KM               0
# EARTHQUAKE_BACKAZIMUTH_DEGREE        0
# DATE_TIME_FIRST_SAMPLE_PRECISION     0
# SAMPLING_INTERVAL_S                  0
# NDATA                                0
# DURATION_S                           0
# STREAM                               0
# UNITS                                0
# INSTRUMENT                           0
# INSTRUMENT_ANALOG/DIGITAL            0
# PGA_CM/S^2                           0
# TIME_PGA_S                           0
# BASELINE_CORRECTION                  0
# FILTER_TYPE                          0
# FILTER_ORDER                         0
# LOW_CUT_FREQUENCY_HZ                 0
# HIGH_CUT_FREQUENCY_HZ                0
# LATE/NORMAL_TRIGGERED                0
# DATA_TYPE                            0
# PROCESSING                           0
# DATA_TIMESTAMP_YYYYMMDD_HHMMSS       0
# ORIGINAL_DATA_MEDIATOR               0
# EVENT_DATE                           0
# DATE_TIME_FIRST_SAMPLE               0
# CHANNEL                              0
# dtype: int64

# %% [markdown]
# # 4. Post-preprocessing check

# %%
missing = df_meta_clean.isnull().mean().sort_values(ascending=False) * 100
print(missing[missing > 0].round(2).to_string())
# Out:
# SITE_CLASSIFICATION_EC8    27.27
# LOCATION                   22.73

# %%
print(df_meta_clean.columns.tolist())
print(df_meta_clean.dtypes)
# Out:
# ['file', 'EVENT_ID', 'EVENT_LATITUDE_DEGREE', 'EVENT_LONGITUDE_DEGREE', 'EVENT_DEPTH_KM', 'HYPOCENTER_REFERENCE', 'MAGNITUDE_W', 'MAGNITUDE_W_REFERENCE', 'FOCAL_MECHANISM', 'NETWORK', 'STATION_CODE', 'STATION_NAME', 'STATION_LATITUDE_DEGREE', 'STATION_LONGITUDE_DEGREE', 'STATION_ELEVATION_M', 'LOCATION', 'SENSOR_DEPTH_M', 'SITE_CLASSIFICATION_EC8', 'EPICENTRAL_DISTANCE_KM', 'EARTHQUAKE_BACKAZIMUTH_DEGREE', 'DATE_TIME_FIRST_SAMPLE_PRECISION', 'SAMPLING_INTERVAL_S', 'NDATA', 'DURATION_S', 'STREAM', 'UNITS', 'INSTRUMENT', 'INSTRUMENT_ANALOG/DIGITAL', 'PGA_CM/S^2', 'TIME_PGA_S', 'BASELINE_CORRECTION', 'FILTER_TYPE', 'FILTER_ORDER', 'LOW_CUT_FREQUENCY_HZ', 'HIGH_CUT_FREQUENCY_HZ', 'LATE/NORMAL_TRIGGERED', 'DATA_TYPE', 'PROCESSING', 'DATA_TIMESTAMP_YYYYMMDD_HHMMSS', 'ORIGINAL_DATA_MEDIATOR', 'EVENT_DATE', 'DATE_TIME_FIRST_SAMPLE', 'CHANNEL']
# file                                        object
# EVENT_ID                                    object
# EVENT_LATITUDE_DEGREE                      float64
# EVENT_LONGITUDE_DEGREE                     float64
# EVENT_DEPTH_KM                             float64
# HYPOCENTER_REFERENCE                        object
# MAGNITUDE_W                                float64
# MAGNITUDE_W_REFERENCE                       object
# FOCAL_MECHANISM                             object
# NETWORK                                     object
# STATION_CODE                                object
# STATION_NAME                                object
# STATION_LATITUDE_DEGREE                    float64
# STATION_LONGITUDE_DEGREE                   float64
# STATION_ELEVATION_M                          int64
# LOCATION                                    object
# SENSOR_DEPTH_M                             float64
# SITE_CLASSIFICATION_EC8                     object
# EPICENTRAL_DISTANCE_KM                     float64
# EARTHQUAKE_BACKAZIMUTH_DEGREE              float64
# DATE_TIME_FIRST_SAMPLE_PRECISION            object
# SAMPLING_INTERVAL_S                        float64
# NDATA                                        int64
# DURATION_S                                 float64
# STREAM                                      object
# UNITS                                       object
# INSTRUMENT                                  object
# INSTRUMENT_ANALOG/DIGITAL                   object
# PGA_CM/S^2                                 float64
# TIME_PGA_S                                 float64
# BASELINE_CORRECTION                         object
# FILTER_TYPE                                 object
# FILTER_ORDER                                 int64
# LOW_CUT_FREQUENCY_HZ                       float64
# HIGH_CUT_FREQUENCY_HZ                      float64
# LATE/NORMAL_TRIGGERED                       object
# DATA_TYPE                                   object
# PROCESSING                                  object
# DATA_TIMESTAMP_YYYYMMDD_HHMMSS              object
# ORIGINAL_DATA_MEDIATOR                      object
# EVENT_DATE                          datetime64[ns]
# DATE_TIME_FIRST_SAMPLE              datetime64[ns]
# CHANNEL                                     object
# dtype: object
